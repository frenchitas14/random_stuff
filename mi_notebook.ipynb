# %% [markdown]
# # Mi Notebook

# %%
import pandas as pd 
import os 
import numpy as np 
import matplotlib as plt

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/fernandagarciapuente/Desktop/Neuro/S2/NeuroComp/codes

# %%
df = pd.read_csv("rdm_results.csv")

# %%
df.shape
# Out:
# (200, 6)

# %%
df.head()
# Out:
#    trial  coherence direction response  correct  decision_time_ms
# 0      1       0.15      left     left        1            6446.4
# 1      2       0.05     right    right        1            2143.4
# 2      3       0.70      left     left        1            1831.7
# 3      4       0.30      left    right        0             952.0
# 4      5       0.15      left     left        1            1340.9

# %%
n = len(df)
print(f"Number of trials = {n}")

trials_per_coherence = df.groupby("coherence")["trial"].count()
print(trials_per_coherence)
# Out:
# Number of trials = 200
# coherence
# 0.05    30
# 0.15    46
# 0.30    45
# 0.50    41
# 0.70    38
# Name: trial, dtype: int64

# %%
# Out:
# coherence
# 0.05    30
# 0.15    46
# 0.30    45
# 0.50    41
# 0.70    38
# Name: trial, dtype: int64
